# %%
import pandas as pd
df = pd.read_csv('ecommerce_sales_analysis.csv')
df.head(10)
# Out:
#    product_id product_name        category   price  review_score  \
# 0           1    Product_1        Clothing  190.40           1.7
# 1           2    Product_2  Home & Kitchen  475.60           3.2
# 2           3    Product_3            Toys  367.34           4.5
# 3           4    Product_4            Toys  301.34           3.9
# 4           5    Product_5           Books   82.23           4.2
# 5           6    Product_6            Toys   82.22           3.6
# 6           7    Product_7     Electronics   33.75           3.8
# 7           8    Product_8     Electronics  433.76           4.4
# 8           9    Product_9     Electronics  302.55           2.0
# 9          10   Product_10        Clothing  355.50           3.0
#
#    review_count  sales_month_1  sales_month_2  sales_month_3  sales_month_4  \
# 0           220            479            449             92            784
# 1           903             21            989            861            863
# ...

# %%
df.tail(10)
# Out:
#      product_id  product_name        category   price  review_score  \
# 990         991   Product_991            Toys  400.71           4.1
# 991         992   Product_992  Home & Kitchen  348.87           1.6
# 992         993   Product_993  Home & Kitchen  139.71           3.4
# 993         994   Product_994  Home & Kitchen  297.16           1.5
# 994         995   Product_995          Sports  183.68           4.0
# 995         996   Product_996  Home & Kitchen   50.33           3.6
# 996         997   Product_997  Home & Kitchen  459.07           4.8
# 997         998   Product_998          Sports   72.73           1.3
# 998         999   Product_999          Sports  475.37           1.2
# 999        1000  Product_1000            Toys  225.77           2.1
#
#      review_count  sales_month_1  sales_month_2  sales_month_3  sales_month_4  \
# 990           323             58            583            180            888
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_id      1000 non-null   int64
#  1   product_name    1000 non-null   object
#  2   category        1000 non-null   object
#  3   price           1000 non-null   float64
#  4   review_score    1000 non-null   float64
#  5   review_count    1000 non-null   int64
#  6   sales_month_1   1000 non-null   int64
#  7   sales_month_2   1000 non-null   int64
#  8   sales_month_3   1000 non-null   int64
#  9   sales_month_4   1000 non-null   int64
#  10  sales_month_5   1000 non-null   int64
#  11  sales_month_6   1000 non-null   int64
#  12  sales_month_7   1000 non-null   int64
#  13  sales_month_8   1000 non-null   int64
#  14  sales_month_9   1000 non-null   int64
#  15  sales_month_10  1000 non-null   int64
#  16  sales_month_11  1000 non-null   int64
# ...

# %%
shape= df.shape
print(shape)
print(f'The dataset has {shape[0]} rows and {shape[1]}rows')
# Out:
# (1000, 18)
# The dataset has 1000 rows and 18rows

# %%
df.describe(include='object')
# Out:
#        product_name category
# count          1000     1000
# unique         1000        7
# top       Product_1    Books
# freq              1      154

# %%
df.describe()
# Out:
#         product_id        price  review_score  review_count  sales_month_1  \
# count  1000.000000  1000.000000   1000.000000   1000.000000    1000.000000
# mean    500.500000   247.677130      3.027600    526.506000     498.306000
# std     288.819436   144.607983      1.171243    282.269932     289.941478
# min       1.000000     7.290000      1.000000      1.000000       0.000000
# 25%     250.750000   121.810000      2.000000    283.750000     245.500000
# 50%     500.500000   250.920000      3.100000    543.000000     507.500000
# 75%     750.250000   373.435000      4.000000    772.000000     740.750000
# max    1000.000000   499.860000      5.000000    999.000000    1000.000000
#
#        sales_month_2  sales_month_3  sales_month_4  sales_month_5  \
# count    1000.000000    1000.000000    1000.000000    1000.000000
# mean      507.661000     506.739000     503.823000     487.194000
# std       285.992689     294.010873     286.645567     287.844324
# ...

# %%
df['category'].value_counts()
# Out:
# category
# Books             154
# Sports            153
# Toys              151
# Clothing          140
# Health            139
# Electronics       138
# Home & Kitchen    125
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'price', 'review_score',
#        'review_count', 'sales_month_1', 'sales_month_2', 'sales_month_3',
#        'sales_month_4', 'sales_month_5', 'sales_month_6', 'sales_month_7',
#        'sales_month_8', 'sales_month_9', 'sales_month_10', 'sales_month_11',
#        'sales_month_12'],
#       dtype='object')

# %%
sum=df['price'].sum()
print(round(sum,2))
# Out:
# 247677.13

# %%
cat = df.groupby('category')['price'].sum()
cat1 = cat.sort_values(ascending=False)
print(cat1[0:3])
# Out:
# category
# Sports    38895.09
# Books     38713.26
# Toys      37961.85
# Name: price, dtype: float64

# %%
df[0:3]
# Out:
#    product_id product_name        category   price  review_score  \
# 0           1    Product_1        Clothing  190.40           1.7
# 1           2    Product_2  Home & Kitchen  475.60           3.2
# 2           3    Product_3            Toys  367.34           4.5
#
#    review_count  sales_month_1  sales_month_2  sales_month_3  sales_month_4  \
# 0           220            479            449             92            784
# 1           903             21            989            861            863
# 2           163            348            558            567            143
#
#    sales_month_5  sales_month_6  sales_month_7  sales_month_8  sales_month_9  \
# 0            604            904            446            603            807
# 1            524            128            610            436            176
# 2            771            409            290            828            340
#
#    sales_month_10  sales_month_11  sales_month_12
# ...

# %%
df2 = pd.Series(df['price'],name='price_Series', index=df['product_id'])
df2.head()
# Out:
# product_id
# 1    475.60
# 2    367.34
# 3    301.34
# 4     82.23
# 5     82.22
# Name: price_Series, dtype: float64

# %%
df2.describe()
# Out:
# count    999.000000
# mean     247.734464
# std      144.669042
# min        7.290000
# 25%      121.190000
# 50%      251.140000
# 75%      373.620000
# max      499.860000
# Name: price_Series, dtype: float64

# %%
df['review_score'].min()
# Out:
# np.float64(1.0)

# %%
electronics_df = df[
    (df['category'] == 'Electronics') & 
    (df['review_score'] > 4.0)]
electronics_df.head()
# Out:
#      product_id product_name     category   price  review_score  review_count  \
# 7             8    Product_8  Electronics  433.76           4.4           906
# 12           13   Product_13  Electronics  417.06           4.8           618
# 26           27   Product_27  Electronics  103.84           4.4           441
# 79           80   Product_80  Electronics   62.36           4.8           598
# 101         102  Product_102  Electronics  320.02           4.9           853
#
#      sales_month_1  sales_month_2  sales_month_3  sales_month_4  \
# 7              905             83             48            926
# 12             975            525             35            886
# 26             263            568            789            320
# 79             357            366            848            533
# 101            450            412             17            737
#
#      sales_month_5  sales_month_6  sales_month_7  sales_month_8  \
# ...

# %%
df.query("category == 'Electronic' and price>100")
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, category, price, review_score, review_count, sales_month_1, sales_month_2, sales_month_3, sales_month_4, sales_month_5, sales_month_6, sales_month_7, sales_month_8, sales_month_9, sales_month_10, sales_month_11, sales_month_12]
# Index: []

# %%
df.sort_values(by=['price','review_score'], ascending= [False,True])
# Out:
#      product_id product_name        category   price  review_score  \
# 531         532  Product_532           Books  499.86           3.4
# 847         848  Product_848          Health  498.45           1.8
# 532         533  Product_533     Electronics  498.34           3.9
# 475         476  Product_476            Toys  496.52           3.7
# 390         391  Product_391           Books  495.30           1.9
# ..          ...          ...             ...     ...           ...
# 205         206  Product_206           Books    9.55           4.1
# 128         129  Product_129           Books    8.44           2.5
# 72           73   Product_73          Health    7.73           1.2
# 208         209  Product_209     Electronics    7.51           2.1
# 821         822  Product_822  Home & Kitchen    7.29           1.5
#
#      review_count  sales_month_1  sales_month_2  sales_month_3  sales_month_4  \
# 531           162            667             48            734            711
# ...

# %%
sum_work=[f'sales_month_{i}' for i in range(1,13)]
df['total_sales'] = df[sum_work].sum(axis=1)
df.head()
# Out:
#    product_id product_name        category   price  review_score  \
# 0           1    Product_1        Clothing  190.40           1.7
# 1           2    Product_2  Home & Kitchen  475.60           3.2
# 2           3    Product_3            Toys  367.34           4.5
# 3           4    Product_4            Toys  301.34           3.9
# 4           5    Product_5           Books   82.23           4.2
#
#    review_count  sales_month_1  sales_month_2  sales_month_3  sales_month_4  \
# 0           220            479            449             92            784
# 1           903             21            989            861            863
# 2           163            348            558            567            143
# 3           951            725            678             59             15
# 4           220            682            451            649            301
#
#    sales_month_5  sales_month_6  sales_month_7  sales_month_8  sales_month_9  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.barplot(data=df, x='category',y='price')
plt.xlabel('Category',fontsize=14)
plt.ylabel('Price',fontsize=14)
plt.xticks(rotation = 45)
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'Clothing'),
#   Text(1, 0, 'Home & Kitchen'),
#   Text(2, 0, 'Toys'),
#   Text(3, 0, 'Books'),
#   Text(4, 0, 'Electronics'),
#   Text(5, 0, 'Health'),
#   Text(6, 0, 'Sports')])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Group by category and calculate average price
category_prices = df.groupby('category')['price'].mean()

plt.bar(x=category_prices.index, height=category_prices.values)
plt.xlabel('Category')
plt.ylabel('Average Price')
plt.title('Average Price by Category')
plt.xticks(rotation=45)
plt.show()

# %%
df.columns = df.columns.str.capitalize()
df= df.rename(columns= {'Product_name': 'name','Review_score':'reviews'})
df.head()
# Out:
#    Product_id       name        Category   Price  reviews  Review_count  \
# 0           1  Product_1        Clothing  190.40      1.7           220
# 1           2  Product_2  Home & Kitchen  475.60      3.2           903
# 2           3  Product_3            Toys  367.34      4.5           163
# 3           4  Product_4            Toys  301.34      3.9           951
# 4           5  Product_5           Books   82.23      4.2           220
#
#    Sales_month_1  Sales_month_2  Sales_month_3  Sales_month_4  Sales_month_5  \
# 0            479            449             92            784            604
# 1             21            989            861            863            524
# 2            348            558            567            143            771
# 3            725            678             59             15            937
# 4            682            451            649            301            620
#
# ...

# %%
df['price_after_discount'] = df['Price'].apply(lambda x: x-(x*0.1) if x >400 else x)
df.head()
# Out:
#    Product_id       name        Category   Price  reviews  Review_count  \
# 0           1  Product_1        Clothing  190.40      1.7           220
# 1           2  Product_2  Home & Kitchen  475.60      3.2           903
# 2           3  Product_3            Toys  367.34      4.5           163
# 3           4  Product_4            Toys  301.34      3.9           951
# 4           5  Product_5           Books   82.23      4.2           220
#
#    Sales_month_1  Sales_month_2  Sales_month_3  Sales_month_4  Sales_month_5  \
# 0            479            449             92            784            604
# 1             21            989            861            863            524
# 2            348            558            567            143            771
# 3            725            678             59             15            937
# 4            682            451            649            301            620
#
# ...

# %%
df.isnull().sum()
# Out:
# Product_id              0
# name                    0
# Category                0
# Price                   0
# reviews                 0
# Review_count            0
# Sales_month_1           0
# Sales_month_2           0
# Sales_month_3           0
# Sales_month_4           0
# Sales_month_5           0
# Sales_month_6           0
# Sales_month_7           0
# Sales_month_8           0
# Sales_month_9           0
# Sales_month_10          0
# Sales_month_11          0
# Sales_month_12          0
# Total_sales             0
# price_after_discount    0
# dtype: int64

# %%
df.drop(['reviews'],axis=1)
# Out:
#      Product_id          name        Category   Price  Review_count  \
# 0             1     Product_1        Clothing  190.40           220
# 1             2     Product_2  Home & Kitchen  475.60           903
# 2             3     Product_3            Toys  367.34           163
# 3             4     Product_4            Toys  301.34           951
# 4             5     Product_5           Books   82.23           220
# ..          ...           ...             ...     ...           ...
# 995         996   Product_996  Home & Kitchen   50.33           494
# 996         997   Product_997  Home & Kitchen  459.07           701
# 997         998   Product_998          Sports   72.73           287
# 998         999   Product_999          Sports  475.37           720
# 999        1000  Product_1000            Toys  225.77           114
#
#      Sales_month_1  Sales_month_2  Sales_month_3  Sales_month_4  \
# 0              479            449             92            784
# ...

# %%
df3 = df[(df['Total_sales']>5000)&(df['reviews']<3.0)]
df3.head()
# Out:
#     Product_id        name        Category   Price  reviews  Review_count  \
# 0            1   Product_1        Clothing  190.40      1.7           220
# 8            9   Product_9     Electronics  302.55      2.0           848
# 10          11  Product_11            Toys   15.19      1.9           182
# 16          17  Product_17            Toys  155.60      1.7           556
# 19          20  Product_20  Home & Kitchen  149.16      1.1           228
#
#     Sales_month_1  Sales_month_2  Sales_month_3  Sales_month_4  Sales_month_5  \
# 0             479            449             92            784            604
# 8             809            693            419            106            616
# 10            125            590             12            128             66
# 16            663            821            515            409            989
# 19            285            403            959            907            610
#
# ...

# %%
df.columns.tolist()
# Out:
# ['Product_id',
#  'name',
#  'Category',
#  'Price',
#  'reviews',
#  'Review_count',
#  'Sales_month_1',
#  'Sales_month_2',
#  'Sales_month_3',
#  'Sales_month_4',
#  'Sales_month_5',
#  'Sales_month_6',
#  'Sales_month_7',
#  'Sales_month_8',
#  'Sales_month_9',
#  'Sales_month_10',
#  'Sales_month_11',
#  'Sales_month_12',
#  'Total_sales',
#  'price_after_discount']

# %%
df.groupby('Category')['Price'].mean()
# Out:
# Category
# Books             251.384805
# Clothing          230.041786
# Electronics       239.674275
# Health            265.142590
# Home & Kitchen    239.769680
# Sports            254.216275
# Toys              251.402980
# Name: Price, dtype: float64

# %%
category = df.groupby('Category').agg({
    'Price':'mean',
    'Total_sales':'sum',
    'reviews': 'mean'
})
category
# Out:
#                      Price  Total_sales   reviews
# Category
# Books           251.384805       938229  3.096753
# Clothing        230.041786       826536  2.952143
# Electronics     239.674275       845120  3.143478
# Health          265.142590       834414  3.005036
# Home & Kitchen  239.769680       742141  3.035200
# Sports          254.216275       916371  3.091503
# Toys            251.402980       917101  2.870861

# %%
indices = df.groupby('Category')['Total_sales'].idxmax()
indices
# Out:
# Category
# Books             852
# Clothing          285
# Electronics       223
# Health            733
# Home & Kitchen    821
# Sports            904
# Toys              196
# Name: Total_sales, dtype: int64

# %%
# Get indices of top products in each category
top_product_indices = df.groupby('Category')['Total_sales'].idxmin()
df.loc[top_product_indices]
# Out:
#      Product_id         name        Category   Price  reviews  Review_count  \
# 785         786  Product_786           Books  454.68      4.6           325
# 543         544  Product_544        Clothing  337.49      2.0           913
# 94           95   Product_95     Electronics  386.63      1.9           610
# 122         123  Product_123          Health  162.41      4.4           650
# 665         666  Product_666  Home & Kitchen   80.67      4.4           655
# 178         179  Product_179          Sports  468.68      4.0           504
# 691         692  Product_692            Toys  215.59      3.0           514
#
#      Sales_month_1  Sales_month_2  Sales_month_3  Sales_month_4  \
# 785             37            441             29            501
# 543             89            732            438             32
# 94              12            325             37             72
# 122             52            283            309            155
# ...

# %%
annual_sales= [f'Sales_month_{i}'for i in range(1,13)]
df_drop= df.drop(annual_sales,axis=1)
df_drop.head()
# Out:
#    Product_id       name        Category   Price  reviews  Review_count  \
# 0           1  Product_1        Clothing  190.40      1.7           220
# 1           2  Product_2  Home & Kitchen  475.60      3.2           903
# 2           3  Product_3            Toys  367.34      4.5           163
# 3           4  Product_4            Toys  301.34      3.9           951
# 4           5  Product_5           Books   82.23      4.2           220
#
#    Total_sales  price_after_discount
# 0         6421                190.40
# 1         6027                428.04
# 2         5580                367.34
# 3         5022                301.34
# 4         6094                 82.23

# %%
# Define the monthly sales columns
monthly_cols = [f'Sales_month_{i}' for i in range(1, 13)]

# Melt the DataFrame
df_long = df.melt(
    id_vars=['Product_id', 'Category'],  # Columns to keep as identifiers
    value_vars=monthly_cols,             # Columns to unpivot
    var_name='month',                    # Name for the new month column
    value_name='sales'                   # Name for the new sales column
)

# Clean up the month column to show just numbers
df_long['month'] = df_long['month'].str.replace('Sales_month_', '').astype(int)

print(df_long.head(10))
# Out:
#    Product_id        Category  month  sales
# 0           1        Clothing      1    479
# 1           2  Home & Kitchen      1     21
# 2           3            Toys      1    348
# 3           4            Toys      1    725
# 4           5           Books      1    682
# 5           6            Toys      1    834
# 6           7     Electronics      1    565
# 7           8     Electronics      1    905
# 8           9     Electronics      1    809
# 9          10        Clothing      1    319

# %%
print(f'pandas version:{pd.__version__}')
# Out:
# pandas version:2.3.3

# %%
temperatures = pd.Series([0,10,20,30,40,50,60], name= 'Temperatures', index =['A','B','C','D','E','F','G'])
print(temperatures)
# Out:
# A     0
# B    10
# C    20
# D    30
# E    40
# F    50
# G    60
# Name: Temperatures, dtype: int64

# %% [markdown]
# **CHAT GBT**

# %%
df=pd.Series([15.99, 23.50, 8.75, 45.25, 32.99],index= ['A001', 'A002', 'A003', 'A004', 'A005'])
print(f'The first 5 rows are\n {df.head()}')
print('\nThe last 2 rows are\n',df.tail(2))
print('\nThe mean price is:',df.mean())
print('\nThe maximum price is:',df.max())
print('\nThe product code is:',df.idxmax())
# Out:
# The first 5 rows are
#  A001    15.99
# A002    23.50
# A003     8.75
# A004    45.25
# A005    32.99
# dtype: float64
#
# The last 2 rows are
#  A004    45.25
# A005    32.99
# dtype: float64
#
# The mean price is: 25.296000000000003
#
# The maximum price is: 45.25
#
# The product code is: A004

# %%
data= {'Title':['Python Basics', 'Data Science', 'Machine Learning', 'Deep Learning'],
       'Author':['John Doe', 'Jane Smith', 'Emily Davis', 'Michael Brown'],
       'Price': [29.99, 39.99, 49.99, 59.99],
       'Year': [2020, 2021, 2022, 2023],
       'Stock': [15, 8, 12, 5]}
df_books =pd.DataFrame(data)
df_books
# Out:
#               Title         Author  Price  Year  Stock
# 0     Python Basics       John Doe  29.99  2020     15
# 1      Data Science     Jane Smith  39.99  2021      8
# 2  Machine Learning    Emily Davis  49.99  2022     12
# 3     Deep Learning  Michael Brown  59.99  2023      5

# %%
df.to_csv('book.csv',index= False)

# %%
df_books.describe()
# Out:
#            Price         Year      Stock
# count   4.000000     4.000000   4.000000
# mean   44.990000  2021.500000  10.000000
# std    12.909944     1.290994   4.396969
# min    29.990000  2020.000000   5.000000
# 25%    37.490000  2020.750000   7.250000
# 50%    44.990000  2021.500000  10.000000
# 75%    52.490000  2022.250000  12.750000
# max    59.990000  2023.000000  15.000000

# %%
df_books[df_books['Year']>2021]
# Out:
#               Title         Author  Price  Year  Stock
# 2  Machine Learning    Emily Davis  49.99  2022     12
# 3     Deep Learning  Michael Brown  59.99  2023      5

# %%
df_books[df_books['Stock']<10]
# Out:
#            Title         Author  Price  Year  Stock
# 1   Data Science     Jane Smith  39.99  2021      8
# 3  Deep Learning  Michael Brown  59.99  2023      5

# %%
df_books[['Title','Price']]
# Out:
#               Title  Price
# 0     Python Basics  29.99
# 1      Data Science  39.99
# 2  Machine Learning  49.99
# 3     Deep Learning  59.99

# %%
df_books.loc[0:1,['Title','Author']]
# Out:
#            Title      Author
# 0  Python Basics    John Doe
# 1   Data Science  Jane Smith

# %%
df_books.iloc[0:2,0:3]
# Out:
#            Title      Author  Price
# 0  Python Basics    John Doe  29.99
# 1   Data Science  Jane Smith  39.99

# %%
df_books[df_books['Title'].str.contains('Python')]
# Out:
#            Title    Author  Price  Year  Stock
# 0  Python Basics  John Doe  29.99  2020     15

# %%
data2= {'Title':['Numpy'],
       'Author':['Kenneth'],
       'Price': [79.99],
       'Year': [2024],
       'Stock': [7]}
df_books2 = pd.DataFrame(data2)

# %%
join= pd.concat([df_books,df_books2],ignore_index=True)
join
# Out:
#               Title         Author  Price  Year  Stock
# 0     Python Basics       John Doe  29.99  2020     15
# 1      Data Science     Jane Smith  39.99  2021      8
# 2  Machine Learning    Emily Davis  49.99  2022     12
# 3     Deep Learning  Michael Brown  59.99  2023      5
# 4             Numpy        Kenneth  79.99  2024      7

# %%
join['average']= join[['Price','Year','Stock']].sum(axis=1)
join
# Out:
#               Title         Author  Price  Year  Stock  average
# 0     Python Basics       John Doe  29.99  2020     15  2064.99
# 1      Data Science     Jane Smith  39.99  2021      8  2068.99
# 2  Machine Learning    Emily Davis  49.99  2022     12  2083.99
# 3     Deep Learning  Michael Brown  59.99  2023      5  2087.99
# 4             Numpy        Kenneth  79.99  2024      7  2110.99

# %%
join[0:1]
# Out:
#            Title    Author  Price  Year  Stock  average
# 0  Python Basics  John Doe  29.99  2020     15  2064.99

# %%
data = {
    'customer_id': [101, 102, 103, 104, 101, None],
    'customer name': ['Alice Smith', 'bob jones', 'Carol Wilson', 'DAVID BROWN', 'alice smith', 'Eva Davis'],
    'order_value': [150.0, None, 200.0, 180.5, 150.0, None],
    'city': ['New York', 'london', 'Paris', 'NEW YORK', 'New York', 'berlin']
}
df_cus = pd.DataFrame(data)
df_cus.head(10)
# Out:
#    customer_id customer name  order_value      city
# 0        101.0   Alice Smith        150.0  New York
# 1        102.0     bob jones          NaN    london
# 2        103.0  Carol Wilson        200.0     Paris
# 3        104.0   DAVID BROWN        180.5  NEW YORK
# 4        101.0   alice smith        150.0  New York
# 5          NaN     Eva Davis          NaN    berlin

# %%
df_cus.drop_duplicates(subset= ['customer name'],keep ='first')
# Out:
#    customer_id customer name  order_value      city
# 0        101.0   Alice Smith        150.0  New York
# 1        102.0     bob jones          NaN    london
# 2        103.0  Carol Wilson        200.0     Paris
# 3        104.0   DAVID BROWN        180.5  NEW YORK
# 4        101.0   alice smith        150.0  New York
# 5          NaN     Eva Davis          NaN    berlin

# %%
df_cus=df_cus.fillna({'order_value':df_cus['order_value'].mean()})
df_cus
# Out:
#    customer_id customer name  order_value      city
# 0        101.0   Alice Smith      150.000  New York
# 1        102.0     bob jones      170.125    london
# 2        103.0  Carol Wilson      200.000     Paris
# 3        104.0   DAVID BROWN      180.500  NEW YORK
# 4        101.0   alice smith      150.000  New York
# 5          NaN     Eva Davis      170.125    berlin

# %%
df_cus['customer_id']=df_cus['customer_id'].fillna(df_cus['customer_id'].mean())
df_cus
# Out:
#    customer_id customer name  order_value      city
# 0        101.0   Alice Smith      150.000  New York
# 1        102.0     bob jones      170.125    london
# 2        103.0  Carol Wilson      200.000     Paris
# 3        104.0   DAVID BROWN      180.500  NEW YORK
# 4        101.0   alice smith      150.000  New York
# 5        102.2     Eva Davis      170.125    berlin

# %%
df_cus
# Out:
#    customer_id customer name  order_value      city
# 0        101.0   Alice Smith      150.000  New York
# 1        102.0     bob jones      170.125    london
# 2        103.0  Carol Wilson      200.000     Paris
# 3        104.0   DAVID BROWN      180.500  NEW YORK
# 4        101.0   alice smith      150.000  New York
# 5        102.2     Eva Davis      170.125    berlin

# %%
df_cus['city']= df_cus['city'].str.title()
df_cus
# Out:
#    customer_id customer name  order_value      city
# 0        101.0   Alice Smith      150.000  New York
# 1        102.0     bob jones      170.125    London
# 2        103.0  Carol Wilson      200.000     Paris
# 3        104.0   DAVID BROWN      180.500  New York
# 4        101.0   alice smith      150.000  New York
# 5        102.2     Eva Davis      170.125    Berlin

# %%
df_cus['customer name'] = df_cus['customer name'].str.title()
df_cus
# Out:
#    customer_id customer name  order_value      city
# 0        101.0   Alice Smith      150.000  New York
# 1        102.0     Bob Jones      170.125    London
# 2        103.0  Carol Wilson      200.000     Paris
# 3        104.0   David Brown      180.500  New York
# 4        101.0   Alice Smith      150.000  New York
# 5        102.2     Eva Davis      170.125    Berlin

# %%
df_cus['email']= df_cus['customer name'].str.split().str[0] + '.' + df_cus['customer name'].str.split().str[1] + '@company.com'
df_cus
# Out:
#    customer_id customer name  order_value      city                     email
# 0        101.0   Alice Smith      150.000  New York   Alice.Smith@company.com
# 1        102.0     Bob Jones      170.125    London     Bob.Jones@company.com
# 2        103.0  Carol Wilson      200.000     Paris  Carol.Wilson@company.com
# 3        104.0   David Brown      180.500  New York   David.Brown@company.com
# 4        101.0   Alice Smith      150.000  New York   Alice.Smith@company.com
# 5        102.2     Eva Davis      170.125    Berlin     Eva.Davis@company.com

# %%
def value(x):
    value = ''
    if x < 100:
        value = 'Small'
    elif 100 <= x < 200:
        value = 'Medium'
    elif x>=200:
        value = 'Large'
    return value 
df_cus['order_category'] = df_cus['order_value'].apply(lambda x: value(x))
df_cus
# Out:
#    customer_id customer name  order_value      city                     email  \
# 0        101.0   Alice Smith      150.000  New York   Alice.Smith@company.com
# 1        102.0     Bob Jones      170.125    London     Bob.Jones@company.com
# 2        103.0  Carol Wilson      200.000     Paris  Carol.Wilson@company.com
# 3        104.0   David Brown      180.500  New York   David.Brown@company.com
# 4        101.0   Alice Smith      150.000  New York   Alice.Smith@company.com
# 5        102.2     Eva Davis      170.125    Berlin     Eva.Davis@company.com
#
#   order_category
# 0         Medium
# 1         Medium
# 2          Large
# 3         Medium
# 4         Medium
# 5         Medium

# %%
df_cus['region']= df_cus['city'].apply(lambda x: 'Americas' if x == 'New York' else 'Europe')
df_cus
# Out:
#    customer_id customer name  order_value      city                     email  \
# 0        101.0   Alice Smith      150.000  New York   Alice.Smith@company.com
# 1        102.0     Bob Jones      170.125    London     Bob.Jones@company.com
# 2        103.0  Carol Wilson      200.000     Paris  Carol.Wilson@company.com
# 3        104.0   David Brown      180.500  New York   David.Brown@company.com
# 4        101.0   Alice Smith      150.000  New York   Alice.Smith@company.com
# 5        102.2     Eva Davis      170.125    Berlin     Eva.Davis@company.com
#
#   order_category    region
# 0         Medium  Americas
# 1         Medium    Europe
# 2          Large    Europe
# 3         Medium  Americas
# 4         Medium  Americas
# 5         Medium    Europe

# %%
df_cus['order_value'].dtypes
df_cus['order_value']= df_cus['order_value'].astype('int32')
df_cus
# Out:
#    customer_id customer name  order_value      city                     email  \
# 0        101.0   Alice Smith          150  New York   Alice.Smith@company.com
# 1        102.0     Bob Jones          170    London     Bob.Jones@company.com
# 2        103.0  Carol Wilson          200     Paris  Carol.Wilson@company.com
# 3        104.0   David Brown          180  New York   David.Brown@company.com
# 4        101.0   Alice Smith          150  New York   Alice.Smith@company.com
# 5        102.2     Eva Davis          170    Berlin     Eva.Davis@company.com
#
#   order_category    region
# 0         Medium  Americas
# 1         Medium    Europe
# 2          Large    Europe
# 3         Medium  Americas
# 4         Medium  Americas
# 5         Medium    Europe

# %%
products = pd.DataFrame({
    'product_code': ['A-100', 'B-250-XL', 'C-300-PRO', 'D-150-LITE'],
    'description': ['red widget', 'BLUE GADGET', 'Green Tool premium', 'yellow device basic']
})
products
# Out:
#   product_code          description
# 0        A-100           red widget
# 1     B-250-XL          BLUE GADGET
# 2    C-300-PRO   Green Tool premium
# 3   D-150-LITE  yellow device basic

# %%
products['description'] = products['description'].str.title()
products
# Out:
#   product_code          description
# 0        A-100           Red Widget
# 1     B-250-XL          Blue Gadget
# 2    C-300-PRO   Green Tool Premium
# 3   D-150-LITE  Yellow Device Basic

# %%
products['size'] = products['product_code'].str.split('-').str[2]
products
# Out:
#   product_code          description  size
# 0        A-100           Red Widget   NaN
# 1     B-250-XL          Blue Gadget    XL
# 2    C-300-PRO   Green Tool Premium   PRO
# 3   D-150-LITE  Yellow Device Basic  LITE

# %%
products['name'] = products['description'].str.split().str[0]+products['product_code'].str.split('-').str[0]+products['size']
products
# Out:
#   product_code          description  size         name
# 0        A-100           Red Widget   NaN          NaN
# 1     B-250-XL          Blue Gadget    XL      BlueBXL
# 2    C-300-PRO   Green Tool Premium   PRO    GreenCPRO
# 3   D-150-LITE  Yellow Device Basic  LITE  YellowDLITE

# %%
orders = pd.DataFrame({
    'order_id': [1001, 1002, 1003, 1004, 1001, 1005],
    'customer_email': ['ALICE@email.com', 'bob@mail.com', 'carol@email.com', 'DAVID@mail.com', 'alice@email.com', None],
    'product': ['laptop', 'mouse', 'keyboard', 'monitor', 'laptop', 'headphones'],
    'price': [999.99, 25.50, 75.00, 299.99, 999.99, 150.00],
    'quantity': [1, 2, 1, 1, 1, None],
    'order_date': ['2023-01-15', '2023-01-15', '2023-01-16', '2023-01-16', '2023-01-15', '2023-01-17']
})
orders
# Out:
#    order_id   customer_email     product   price  quantity  order_date
# 0      1001  ALICE@email.com      laptop  999.99       1.0  2023-01-15
# 1      1002     bob@mail.com       mouse   25.50       2.0  2023-01-15
# 2      1003  carol@email.com    keyboard   75.00       1.0  2023-01-16
# 3      1004   DAVID@mail.com     monitor  299.99       1.0  2023-01-16
# 4      1001  alice@email.com      laptop  999.99       1.0  2023-01-15
# 5      1005             None  headphones  150.00       NaN  2023-01-17

# %%
orders['order_id'].duplicated().sum()
# Out:
# np.int64(1)

# %%
orders.dropna(subset= ['customer_email'], inplace = True)

# %%
orders['customer_email']= orders['customer_email'].str.title()
orders
# Out:
#    order_id   customer_email   product   price  quantity  order_date
# 0      1001  Alice@Email.Com    laptop  999.99       1.0  2023-01-15
# 1      1002     Bob@Mail.Com     mouse   25.50       2.0  2023-01-15
# 2      1003  Carol@Email.Com  keyboard   75.00       1.0  2023-01-16
# 3      1004   David@Mail.Com   monitor  299.99       1.0  2023-01-16
# 4      1001  Alice@Email.Com    laptop  999.99       1.0  2023-01-15

# %%
orders.duplicated().sum()
# Out:
# np.int64(1)

# %%
orders.drop_duplicates()
# Out:
#    order_id   customer_email   product   price  quantity  order_date
# 0      1001  Alice@Email.Com    laptop  999.99       1.0  2023-01-15
# 1      1002     Bob@Mail.Com     mouse   25.50       2.0  2023-01-15
# 2      1003  Carol@Email.Com  keyboard   75.00       1.0  2023-01-16
# 3      1004   David@Mail.Com   monitor  299.99       1.0  2023-01-16

# %%
orders['total_value']= orders['price']* orders['quantity']
orders
# Out:
#    order_id   customer_email   product   price  quantity  order_date  \
# 0      1001  Alice@Email.Com    laptop  999.99       1.0  2023-01-15
# 1      1002     Bob@Mail.Com     mouse   25.50       2.0  2023-01-15
# 2      1003  Carol@Email.Com  keyboard   75.00       1.0  2023-01-16
# 3      1004   David@Mail.Com   monitor  299.99       1.0  2023-01-16
# 4      1001  Alice@Email.Com    laptop  999.99       1.0  2023-01-15
#
#    total_value
# 0       999.99
# 1        51.00
# 2        75.00
# 3       299.99
# 4       999.99

# %%
orders['order_date'] = pd.to_datetime(orders['order_date'])
orders['day'] = orders['order_date'].dt.day_name()
orders['month'] = orders['order_date'].dt.month_name()
orders['year'] = orders['order_date'].dt.year
orders
# Out:
#    order_id   customer_email   product   price  quantity order_date  \
# 0      1001  Alice@Email.Com    laptop  999.99       1.0 2023-01-15
# 1      1002     Bob@Mail.Com     mouse   25.50       2.0 2023-01-15
# 2      1003  Carol@Email.Com  keyboard   75.00       1.0 2023-01-16
# 3      1004   David@Mail.Com   monitor  299.99       1.0 2023-01-16
# 4      1001  Alice@Email.Com    laptop  999.99       1.0 2023-01-15
#
#    total_value     day    month  year
# 0       999.99  Sunday  January  2023
# 1        51.00  Sunday  January  2023
# 2        75.00  Monday  January  2023
# 3       299.99  Monday  January  2023
# 4       999.99  Sunday  January  2023

# %%
orders.to_csv('order.csv',index=False)

# %%
orders = orders.sort_index(axis= 1)
orders
# Out:
#     customer_email     day    month order_date  order_id   price   product  \
# 0  Alice@Email.Com  Sunday  January 2023-01-15      1001  999.99    laptop
# 1     Bob@Mail.Com  Sunday  January 2023-01-15      1002   25.50     mouse
# 2  Carol@Email.Com  Monday  January 2023-01-16      1003   75.00  keyboard
# 3   David@Mail.Com  Monday  January 2023-01-16      1004  299.99   monitor
# 4  Alice@Email.Com  Sunday  January 2023-01-15      1001  999.99    laptop
#
#    quantity  total_value  year
# 0       1.0       999.99  2023
# 1       2.0        51.00  2023
# 2       1.0        75.00  2023
# 3       1.0       299.99  2023
# 4       1.0       999.99  2023

# %%
orders.drop_duplicates(subset=['customer_email'])
# Out:
#     customer_email     day    month order_date  order_id   price   product  \
# 0  Alice@Email.Com  Sunday  January 2023-01-15      1001  999.99    laptop
# 1     Bob@Mail.Com  Sunday  January 2023-01-15      1002   25.50     mouse
# 2  Carol@Email.Com  Monday  January 2023-01-16      1003   75.00  keyboard
# 3   David@Mail.Com  Monday  January 2023-01-16      1004  299.99   monitor
#
#    quantity  total_value  year
# 0       1.0       999.99  2023
# 1       2.0        51.00  2023
# 2       1.0        75.00  2023
# 3       1.0       299.99  2023

# %%
orders.groupby('customer_email').size()
# Out:
# customer_email
# Alice@Email.Com    2
# Bob@Mail.Com       1
# Carol@Email.Com    1
# David@Mail.Com     1
# dtype: int64

# %%
# Sales data
sales = pd.DataFrame({
    'Region': ['North', 'South', 'North', 'South', 'East', 'West', 'East', 'West'],
    'Product': ['A', 'A', 'B', 'B', 'A', 'B', 'A', 'B'],
    'Salesperson': ['John', 'Jane', 'John', 'Jane', 'Mike', 'Sarah', 'Mike', 'Sarah'],
    'Revenue': [1000, 1200, 800, 900, 1100, 950, 1300, 850],
    'Units': [10, 12, 8, 9, 11, 10, 13, 9]
})
sales.head(10)
# Out:
#   Region Product Salesperson  Revenue  Units
# 0  North       A        John     1000     10
# 1  South       A        Jane     1200     12
# 2  North       B        John      800      8
# 3  South       B        Jane      900      9
# 4   East       A        Mike     1100     11
# 5   West       B       Sarah      950     10
# 6   East       A        Mike     1300     13
# 7   West       B       Sarah      850      9

# %%
sales.groupby('Region')['Revenue'].sum()
# Out:
# Region
# East     2400
# North    1800
# South    2100
# West     1800
# Name: Revenue, dtype: int64

# %%
sales.groupby('Product')['Revenue'].sum()
# Out:
# Product
# A    4600
# B    3500
# Name: Revenue, dtype: int64

# %%
sales.groupby('Salesperson').size()
# Out:
# Salesperson
# Jane     2
# John     2
# Mike     2
# Sarah    2
# dtype: int64

# %%
sales.groupby(['Region','Product'])['Revenue'].max().reset_index()
# Out:
#   Region Product  Revenue
# 0   East       A     1300
# 1  North       A     1000
# 2  North       B      800
# 3  South       A     1200
# 4  South       B      900
# 5   West       B      950

# %%
sales.groupby(['Region','Product']).agg({
    'Revenue':'sum',
    'Units':'sum'})
# Out:
#                 Revenue  Units
# Region Product
# East   A           2400     24
# North  A           1000     10
#        B            800      8
# South  A           1200     12
#        B            900      9
# West   B           1800     19

# %%
sales.groupby(['Region','Salesperson'])['Revenue'].mean().reset_index()
# Out:
#   Region Salesperson  Revenue
# 0   East        Mike   1200.0
# 1  North        John    900.0
# 2  South        Jane   1050.0
# 3   West       Sarah    900.0

# %%
result = sales.groupby('Product').agg({'Revenue':[lambda x: x.max()-x.min()]})
result.columns = ['_'.join(col).split() for col in result.columns]
result
# Out:
#         Revenue_<lambda>
# Product
# A                    300
# B                    150

# %%
sales.groupby(['Region','Product'])['Revenue'].agg(['count','mean','std']).reset_index()
# Out:
#   Region Product  count    mean         std
# 0   East       A      2  1200.0  141.421356
# 1  North       A      1  1000.0         NaN
# 2  North       B      1   800.0         NaN
# 3  South       A      1  1200.0         NaN
# 4  South       B      1   900.0         NaN
# 5   West       B      2   900.0   70.710678

# %%
sales.head()
# Out:
#   Region Product Salesperson  Revenue  Units
# 0  North       A        John     1000     10
# 1  South       A        Jane     1200     12
# 2  North       B        John      800      8
# 3  South       B        Jane      900      9
# 4   East       A        Mike     1100     11

# %%
pivot= pd.pivot_table(sales,
               values='Revenue',
               columns= 'Product',
               index= 'Region',
               aggfunc = 'mean',
               fill_value = 0)
pivot.head()
# Out:
# Product       A      B
# Region
# East     1200.0    0.0
# North    1000.0  800.0
# South    1200.0  900.0
# West        0.0  900.0

# %%
pivot1 = pd.pivot_table(sales,
                        values = ['Revenue','Units'],
                        columns= 'Product',
                        index= 'Region',
                        aggfunc={'Revenue':'sum','Units':'count'},
                        margins = True,
                        margins_name = 'Total')
pivot1.head()
# Out:
#         Revenue               Units
# Product       A       B Total     A    B Total
# Region
# East     2400.0     NaN  2400   2.0  NaN     2
# North    1000.0   800.0  1800   1.0  1.0     2
# South    1200.0   900.0  2100   1.0  1.0     2
# West        NaN  1800.0  1800   NaN  2.0     2
# Total    4600.0  3500.0  8100   4.0  4.0     8

# %%
cross = pd.crosstab(sales['Region'],sales['Product'],
                    margins = True,
                    normalize = 'index')
cross
# Out:
# Product    A    B
# Region
# East     1.0  0.0
# North    0.5  0.5
# South    0.5  0.5
# West     0.0  1.0
# All      0.5  0.5

# %%
sales_data = pd.DataFrame({
    'Month': ['Jan', 'Jan', 'Feb', 'Feb', 'Mar', 'Mar', 'Jan', 'Feb', 'Mar'],
    'Region': ['North', 'South', 'North', 'South', 'North', 'South', 'West', 'West', 'West'],
    'Product': ['Widget', 'Widget', 'Widget', 'Widget', 'Widget', 'Widget', 'Gadget', 'Gadget', 'Gadget'],
    'Revenue': [5000, 7000, 6000, 8000, 5500, 7500, 3000, 4000, 3500],
    'Cost': [3000, 4000, 3500, 4500, 3200, 4200, 1500, 2000, 1800]
})
sales_data.head(20)
# Out:
#   Month Region Product  Revenue  Cost
# 0   Jan  North  Widget     5000  3000
# 1   Jan  South  Widget     7000  4000
# 2   Feb  North  Widget     6000  3500
# 3   Feb  South  Widget     8000  4500
# 4   Mar  North  Widget     5500  3200
# 5   Mar  South  Widget     7500  4200
# 6   Jan   West  Gadget     3000  1500
# 7   Feb   West  Gadget     4000  2000
# 8   Mar   West  Gadget     3500  1800

# %%
sales_data.groupby('Region')['Revenue'].sum()
# Out:
# Region
# North    16500
# South    22500
# West     10500
# Name: Revenue, dtype: int64

# %%
top_products = sales_data.groupby(['Region','Product'])['Revenue'].sum().sort_values(ascending = False)
top_products
# Out:
# Region  Product
# South   Widget     22500
# North   Widget     16500
# West    Gadget     10500
# Name: Revenue, dtype: int64

# %%
top_products = (
    sales_data.groupby(['Region', 'Product'])['Revenue']
    .sum()
    .sort_values(ascending=False)
    .groupby(level=1)
    .head(2)
)
top_products
# Out:
# Region  Product
# South   Widget     22500
# North   Widget     16500
# West    Gadget     10500
# Name: Revenue, dtype: int64

# %%
sales_data['Profit'] = sales_data['Revenue'] - sales_data['Cost']

# %%
sales_data.groupby(['Region','Month'])['Profit'].sum()
# Out:
# Region  Month
# North   Feb      2500
#         Jan      2000
#         Mar      2300
# South   Feb      3500
#         Jan      3000
#         Mar      3300
# West    Feb      2000
#         Jan      1500
#         Mar      1700
# Name: Profit, dtype: int64

# %%
month = pd.pivot_table(sales_data,
               values = 'Revenue',
               columns = 'Month',
               index = 'Region',
               aggfunc = 'sum',
               fill_value = 0)
month
# Out:
# Month    Feb   Jan   Mar
# Region
# North   6000  5000  5500
# South   8000  7000  7500
# West    4000  3000  3500

# %%
sales_data.groupby(['Region','Month'])['Profit'].sum().idxmax()
# Out:
# ('South', 'Feb')

# %%
df1 = pd.DataFrame({'A': [1, 2], 'B': [3, 4]})
df2 = pd.DataFrame({'A': [5, 6], 'B': [7, 8]})
pd.concat([df1,df2],ignore_index = True)
# Out:
#    A  B
# 0  1  3
# 1  2  4
# 2  5  7
# 3  6  8

# %%
df3 = pd.DataFrame({'C': [9, 10], 'D': [11, 12]})
pd.concat([df1,df3],axis = 1)
# Out:
#    A  B   C   D
# 0  1  3   9  11
# 1  2  4  10  12

# %%
df1 = pd.DataFrame({'Product': ['A', 'B'], 'Q1_Sales': [100, 150]})
df2 = pd.DataFrame({'Product': ['C', 'D'], 'Q1_Sales': [200, 180]})
df3 = pd.DataFrame({'Product': ['A', 'B'], 'Q2_Sales': [120, 160]})

b1 = pd.concat([df1,df2],ignore_index= True)
b1
# Out:
#   Product  Q1_Sales
# 0       A       100
# 1       B       150
# 2       C       200
# 3       D       180

# %%
b2= pd.concat([df1,df3['Q2_Sales']],axis = 1)
b2
# Out:
#   Product  Q1_Sales  Q2_Sales
# 0       A       100       120
# 1       B       150       160

# %%
pd.merge(b1,b2,on=['Product','Q1_Sales'],how = 'outer')
# Out:
#   Product  Q1_Sales  Q2_Sales
# 0       A       100     120.0
# 1       B       150     160.0
# 2       C       200       NaN
# 3       D       180       NaN

# %%
customers = pd.DataFrame({
    'customer_id': [1, 2, 3, 4],
    'name': ['Alice', 'Bob', 'Charlie', 'Diana'],
    'city': ['London', 'Paris', 'Berlin', 'Madrid']
})

orders = pd.DataFrame({
    'order_id': [101, 102, 103, 104, 105],
    'customer_id': [1, 2, 1, 5, 3],
    'amount': [150, 200, 100, 300, 250],
    'product': ['Widget', 'Gadget', 'Tool', 'Widget', 'Gadget']
})

lef = pd.merge(customers, orders, on ='customer_id', how= 'left')
lef
# Out:
#    customer_id     name    city  order_id  amount product
# 0            1    Alice  London     101.0   150.0  Widget
# 1            1    Alice  London     103.0   100.0    Tool
# 2            2      Bob   Paris     102.0   200.0  Gadget
# 3            3  Charlie  Berlin     105.0   250.0  Gadget
# 4            4    Diana  Madrid       NaN     NaN     NaN

# %%
pd.merge(customers,orders,on = 'customer_id', how='right')
# Out:
#    customer_id     name    city  order_id  amount product
# 0            1    Alice  London       101     150  Widget
# 1            2      Bob   Paris       102     200  Gadget
# 2            1    Alice  London       103     100    Tool
# 3            5      NaN     NaN       104     300  Widget
# 4            3  Charlie  Berlin       105     250  Gadget

# %%
suma = pd.merge(customers,orders,on='customer_id',how='outer')
suma
# Out:
#    customer_id     name    city  order_id  amount product
# 0            1    Alice  London     101.0   150.0  Widget
# 1            1    Alice  London     103.0   100.0    Tool
# 2            2      Bob   Paris     102.0   200.0  Gadget
# 3            3  Charlie  Berlin     105.0   250.0  Gadget
# 4            4    Diana  Madrid       NaN     NaN     NaN
# 5            5      NaN     NaN     104.0   300.0  Widget

# %%
lef[lef['order_id'].isna()]
# Out:
#    customer_id   name    city  order_id  amount product
# 4            4  Diana  Madrid       NaN     NaN     NaN

# %%
lef.groupby('customer_id')['amount'].sum()
# Out:
# customer_id
# 1    250.0
# 2    200.0
# 3    250.0
# 4      0.0
# Name: amount, dtype: float64

# %%
wide_sales = pd.DataFrame({
    'Region': ['North', 'South'],
    'Product_A_2022': [1000, 1200],
    'Product_B_2022': [800, 900],
    'Product_A_2023': [1100, 1300],
    'Product_B_2023': [850, 950]
})
wide_sales
# Out:
#   Region  Product_A_2022  Product_B_2022  Product_A_2023  Product_B_2023
# 0  North            1000             800            1100             850
# 1  South            1200             900            1300             950

# %%
long =pd.melt(wide_sales,
        id_vars = ['Region'],
        value_vars = ['Product_A_2022','Product_B_2022','Product_A_2023','Product_B_2023'],
        var_name = 'Product',
        value_name = 'Sales')
long
# Out:
#   Region         Product  Sales
# 0  North  Product_A_2022   1000
# 1  South  Product_A_2022   1200
# 2  North  Product_B_2022    800
# 3  South  Product_B_2022    900
# 4  North  Product_A_2023   1100
# 5  South  Product_A_2023   1300
# 6  North  Product_B_2023    850
# 7  South  Product_B_2023    950

# %%
long['Year'] = long['Product'].str.split('_').str[2]
long
# Out:
#   Region         Product  Sales  Year
# 0  North  Product_A_2022   1000  2022
# 1  South  Product_A_2022   1200  2022
# 2  North  Product_B_2022    800  2022
# 3  South  Product_B_2022    900  2022
# 4  North  Product_A_2023   1100  2023
# 5  South  Product_A_2023   1300  2023
# 6  North  Product_B_2023    850  2023
# 7  South  Product_B_2023    950  2023

# %%
long['Product'] = long['Product'].str.split('_').str[0]+'_'+long['Product'].str.split('_').str[1]
long
# Out:
#   Region    Product  Sales  Year
# 0  North  Product_A   1000  2022
# 1  South  Product_A   1200  2022
# 2  North  Product_B    800  2022
# 3  South  Product_B    900  2022
# 4  North  Product_A   1100  2023
# 5  South  Product_A   1300  2023
# 6  North  Product_B    850  2023
# 7  South  Product_B    950  2023

# %%
unstack= pd.pivot_table(long,
                        values = 'Sales',
                        columns = 'Year',
                        index = ['Region','Product'],
                        aggfunc = 'sum')
unstack
# Out:
# Year              2022  2023
# Region Product
# North  Product_A  1000  1100
#        Product_B   800   850
# South  Product_A  1200  1300
#        Product_B   900   950

# %%
unstack.head()
# Out:
# Year              2022  2023
# Region Product
# North  Product_A  1000  1100
#        Product_B   800   850
# South  Product_A  1200  1300
#        Product_B   900   950
